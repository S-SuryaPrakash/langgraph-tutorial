# %%
from dotenv import load_dotenv
import os
load_dotenv()
if os.environ["GOOGLE_API_KEY"]=="" :
    raise ValueError("Please set the GOOGLE_API_KEY environment variable in the .env file.")
else:
    print("GOOGLE_API_KEY is set.")
# Out:
# GOOGLE_API_KEY is set.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAI
llm=ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",  # or "gemini-1.0-pro", "gemini-2.0-flash", etc.
    temperature=1.0,  # Gemini 3.0+ defaults to 1.0
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %%
from langchain_core.prompts import ChatPromptTemplate

my_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that creates social media posts."),
    ("user", "I want to crate a post about {topic}")
])

# prompt_filled = my_prompt.invoke({"topic": "The importance of data privacy in the digital age."})

# %%
# llm.invoke(prompt_filled)

# %%
chain = my_prompt | llm
chain.invoke({"topic": "The importance of data privacy in the digital age."})
# Out:
# AIMessage(content='Great choice! Data privacy is a critical topic. Here are a few options for a social media post, ranging in tone and length, with relevant emojis and hashtags.\n\n---\n\n### Option 1: The "Why It Matters" Post (Slightly longer, informative)\n\n**Image/Video Suggestion:** A lock icon with digital lines, a shielded computer, or a graphic with "Your Data" in the center surrounded by digital "threats."\n\n**Post:**\n🔐 Your digital footprint is growing every day, and so is the importance of keeping it safe! In the digital age, data privacy isn\'t just a tech term—it\'s about protecting your identity, finances, and freedom.\n\nEvery click, share, and sign-up leaves a trace. Understanding who has access to your personal information and how it\'s used is crucial to prevent identity theft, targeted manipulation, and unauthorized access.\n\n💡 **Take control:**\n*   Review privacy settings on apps & social media.\n*   Use strong, unique passwords.\n*   Be wary of suspicious li
# ...
